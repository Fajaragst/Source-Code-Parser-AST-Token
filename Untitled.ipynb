# %% [markdown]
# Source:
# https://github.com/c2nes/javalang
#
# Software Defect Prediction via ConvolutionalNeural Network
#
# Seml: A Semantic LSTM Model for Software Defect Prediction
#
# Automatically Learning Semantic Features for Defect Prediction
#
# https://github.com/kevinqiu1990/TCNN
#
# Transfer Convolutional Neural Network for Cross-Project Defect Prediction

# %%
# !pip3 install javalang
import tensorflow as tf
import javalang
import javalang.tree as jlt
from os import walk
import pandas as pd
from io import StringIO
# Out:
# Requirement already satisfied: javalang in /home/fajaragst/.local/lib/python3.8/site-packages (0.13.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from javalang) (1.14.0)

# %% [markdown]
# 1)Method invocation and class instance creation nodes:
# We extract and record these nodes using their method or
# class names. For example, we extract method pop() and
# push() in File2.java in Figure 1 and record them as pop
# and push.
#
# 2)Declaration nodes: We extract method declaration, type
# declaration and enum declaration nodes, and record them
# using their names.
#
# 3)Control-flow nodes: We extract those statements or
# clauses related to control flow of a program, e.g., if state-
# ment, for statement, while statement, catch clause.
# Control-flow nodes are recorded using their statement types,
# e.g., if statement is recorded as if, and catch clause is recorded
# as catch.
# Therefore
#
# karena hanya 3 aturan yg digunakan maka types node dari AST yg digunakan adalah dibawah ini:

# %%
types = [jlt.FormalParameter, jlt.BasicType, jlt.PackageDeclaration, jlt.InterfaceDeclaration, jlt.CatchClauseParameter,
         jlt.ClassDeclaration, jlt.MethodInvocation, jlt.SuperMethodInvocation, jlt.MemberReference, jlt.SuperMemberReference,
         jlt.ConstructorDeclaration, jlt.ReferenceType, jlt.MethodDeclaration, jlt.VariableDeclarator, jlt.IfStatement,
         jlt.WhileStatement, jlt.DoStatement, jlt.ForStatement, jlt.AssertStatement, jlt.BreakStatement,
         jlt.ContinueStatement, jlt.ReturnStatement, jlt.ThrowStatement, jlt.SynchronizedStatement, jlt.TryStatement,
         jlt.SwitchStatement, jlt.BlockStatement, jlt.StatementExpression, jlt.TryResource, jlt.CatchClause,
         jlt.CatchClauseParameter, jlt.SwitchStatementCase, jlt.ForControl, jlt.EnhancedForControl]

# %% [markdown]
# Function untuk parse dari source code ke AST -> Token
#
# Didefinisikan secara manual

# %%
def parse(source):
    tokens = javalang.parse.parse(source)
    result = []
    for path, node in tokens:
        if isinstance(node, jlt.PackageDeclaration):
            result.append(node.name)
            continue
        if isinstance(node, jlt.IfStatement):
            result.append("if")
            continue
        if isinstance(node, jlt.InterfaceDeclaration):
            result.append(node.name)
            continue
        if isinstance(node, jlt.ClassDeclaration):
            result.append(node.name)
            continue
        if isinstance(node, jlt.MethodInvocation):
            result.append(node.member)
            continue
        if isinstance(node, jlt.MemberReference):
            result.append(node.member)
            continue
        if isinstance(node, jlt.ConstructorDeclaration):
            result.append(node.name)
            continue
        if isinstance(node, jlt.ReferenceType):
            result.append(node.name)
            continue
        if isinstance(node, jlt.MethodDeclaration):
            result.append(node.name)
            continue
        if isinstance(node, jlt.VariableDeclarator):
            result.append(node.name)
            continue
        if isinstance(node, jlt.ThrowStatement):
            result.append("throw")
            continue
        if isinstance(node, jlt.TryStatement):
            result.append("try")
            continue
        if isinstance(node, jlt.BlockStatement):
            result.append("block")
            continue
        if isinstance(node, jlt.CatchClause):
            result.append("catch")
            continue
        if isinstance(node, jlt.ForStatement):
            result.append("for")
            continue
        if isinstance(node, jlt.AssertStatement):
            result.append("assert")
            continue
        if isinstance(node, jlt.BreakStatement):
            result.append("break")
            continue
        if isinstance(node, jlt.ContinueStatement):
            result.append("cotinue")
            continue
        if isinstance(node, jlt.ReturnStatement):
            result.append("return")
            continue
        if isinstance(node, jlt.ReturnStatement):
            result.append("return")
            continue
        if isinstance(node, jlt.ThrowStatement):
            result.append("throw")
            continue
        if isinstance(node, jlt.SwitchStatement):
            result.append("switch")
            continue
        if isinstance(node, jlt.WhileStatement):
            result.append("while")
            continue
        if isinstance(node, jlt.DoStatement):
            result.append("do")
            continue
        if isinstance(node, jlt.CatchClauseParameter):
            result.append(node.types)
            continue
        if isinstance(node, jlt.BasicType):
            result.append(node.name)
            continue
        if isinstance(node, jlt.SynchronizedStatement):
            result.append("Synchronized")
            continue
    return result

# %% [markdown]
# Proses mengubah Source Code (File) -> AST -> Token
#
# Arsitektur Folder
#
#
# "Nama Project"
#
#     "Defect"
#
#         "File Defect 1"
#
#         "File Defect 2"
#
#         ....
#
#     "Non-Defect"
#
#         "File Non-Defect 1"
#
#         "File Non-Defect 2"
#
#         ....

# %%
def Tokenize(dir_name):
    df_list = []
    df = pd.DataFrame(columns=['File','Token','Defect'])
    for (dirpath, dirnames, filenames) in walk(dir_name):
        for label in dirnames: 
            for (dirpath, dirnames, filenames) in walk(dir_name+'/'+label):
                for filename in filenames:
                    f = open(dir_name+'/'+label+'/'+filename, "r")
                    f = f.read()
                    try:
                        p = parse(f)
                    except:
                        continue

                    temp = pd.DataFrame([[filename,p,label]],columns=['File','Token','Defect'])
                    df_list.append(temp)
                break
        break
    df = pd.concat(df_list)
    df = df.reset_index()
    return df

# %%
Token_ant = Tokenize("ant-1.4/")

# %%
Token_ant
# Out:
#      index                  File  \
# 0        0             Exit.java
# 1        0    ConditionTask.java
# 2        0        DependSet.java
# 3        0         ExecTask.java
# 4        0    DefaultLogger.java
# ..     ...                   ...
# 156      0          FixCRLF.java
# 157      0   AntClassLoader.java
# 158      0  LogOutputStream.java
# 159      0  ExecuteWatchdog.java
# 160      0               Sj.java
#
#                                                  Token      Defect
# 0    [org.apache.tools.ant.taskdefs, Exit, String, ...      Defect
# 1    [org.apache.tools.ant.taskdefs, ConditionTask,...      Defect
# 2    [org.apache.tools.ant.taskdefs, DependSet, Vec...      Defect
# 3    [org.apache.tools.ant.taskdefs, ExecTask, Stri...      Defect
# 4    [org.apache.ant.frontend, DefaultLogger, int, ...      Defect
# ..                                                 ...         ...
# 156  [org.apache.tools.ant.taskdefs, FixCRLF, int, ...  Non-Defect
# 157  [org.apache.ant.core.support, AntClassLoader, ...  Non-Defect
# 158  [org.apache.tools.ant.taskdefs, LogOutputStrea...  Non-Defect
# 159  [org.apache.tools.ant.taskdefs, ExecuteWatchdo...  Non-Defect
# 160  [org.apache.tools.ant.taskdefs.compilers, Sj, ...  Non-Defect
#
# [161 rows x 4 columns]

# %%
Token.Token[8]
# Out:
# ['org.apache.tools.ant.taskdefs',
#  'Execute',
#  'int',
#  'INVALID',
#  'MAX_VALUE',
#  'String',
#  'cmdl',
#  'String',
#  'env',
#  'int',
#  'exitValue',
#  'INVALID',
#  'ExecuteStreamHandler',
#  'streamHandler',
#  'ExecuteWatchdog',
#  'watchdog',
#  'File',
#  'workingDirectory',
#  'Project',
#  'project',
#  'boolean',
#  'newEnvironment',
#  'boolean',
#  'useVMLauncher',
#  'String',
#  'antWorkingDirectory',
#  'getProperty',
#  'CommandLauncher',
#  'vmLauncher',
#  'CommandLauncher',
#  'shellLauncher',
#  'Vector',
#  'procEnvironment',
#  'try',
#  'vmLauncher',
#  'Java13CommandLauncher',
#  'catch',
#  ['NoSuchMethodException'],
#  'String',
#  'osname',
#  'getProperty',
#  'toLowerCase',
#  'if',
#  'indexOf',
#  'block',
#  'shellLauncher',
#  'MacCommandLauncher',
#  'CommandLauncher',
#  'if',
#  'indexOf',
#  'block',
#  'shellLauncher',
#  'WinNTCommandLauncher',
#  'CommandLauncher',
#  'if',
#  'indexOf',
#  'block',
#  'CommandLauncher',
#  'baseLauncher',
#  'if',
#  'getProperty',
#  'startsWith',
#  'block',
#  'baseLauncher',
#  'Java11CommandLauncher',
#  'block',
#  'baseLauncher',
#  'CommandLauncher',
#  'if',
#  'indexOf',
#  'indexOf',
#  'block',
#  'shellLauncher',
#  'WinNTCommandLauncher',
#  'baseLauncher',
#  'block',
#  'shellLauncher',
#  'ScriptCommandLauncher',
#  'baseLauncher',
#  'block',
#  'shellLauncher',
#  'ScriptCommandLauncher',
#  'CommandLauncher',
#  'getProcEnvironment',
#  'Vector',
#  'if',
#  'procEnvironment',
#  'return',
#  'procEnvironment',
#  'procEnvironment',
#  'Vector',
#  'try',
#  'ByteArrayOutputStream',
#  'out',
#  'ByteArrayOutputStream',
#  'Execute',
#  'exe',
#  'Execute',
#  'PumpStreamHandler',
#  'out',
#  'setCommandline',
#  'getProcEnvCommand',
#  'setNewenvironment',
#  'int',
#  'retval',
#  'execute',
#  'if',
#  'retval',
#  'block',
#  'BufferedReader',
#  'in',
#  'BufferedReader',
#  'StringReader',
#  'toString',
#  'String',
#  'var',
#  'String',
#  'line',
#  'lineSep',
#  'getProperty',
#  'while',
#  'line',
#  'readLine',
#  'block',
#  'if',
#  'indexOf',
#  'block',
#  'if',
#  'var',
#  'block',
#  'var',
#  'lineSep',
#  'line',
#  'block',
#  'var',
#  'lineSep',
#  'line',
#  'block',
#  'if',
#  'var',
#  'block',
#  'addElement',
#  'var',
#  'var',
#  'line',
#  'addElement',
#  'var',
#  'catch',
#  ['java.io.IOException'],
#  'printStackTrace',
#  'return',
#  'procEnvironment',
#  'getProcEnvCommand',
#  'String',
#  'String',
#  'osname',
#  'getProperty',
#  'toLowerCase',
#  'if',
#  'indexOf',
#  'block',
#  'try',
#  'String',
#  'version',
#  'getProperty',
#  'int',
#  'majorVersion',
#  'parseInt',
#  'substring',
#  'indexOf',
#  'if',
#  'majorVersion',
#  'block',
#  'String',
#  'cmd',
#  'return',
#  'cmd',
#  'catch',
#  ['NumberFormatException'],
#  'String',
#  'cmd',
#  'return',
#  'cmd',
#  'if',
#  'indexOf',
#  'block',
#  'String',
#  'cmd',
#  'return',
#  'cmd',
#  'if',
#  'indexOf',
#  'block',
#  'if',
#  'indexOf',
#  'indexOf',
#  'block',
#  'String',
#  'cmd',
#  'return',
#  'cmd',
#  'block',
#  'String',
#  'cmd',
#  'return',
#  'cmd',
#  'block',
#  'String',
#  'cmd',
#  'return',
#  'cmd',
#  'Execute',
#  'PumpStreamHandler',
#  'Execute',
#  'ExecuteStreamHandler',
#  'streamHandler',
#  'Execute',
#  'ExecuteStreamHandler',
#  'ExecuteWatchdog',
#  'streamHandler',
#  'streamHandler',
#  'watchdog',
#  'watchdog',
#  'getCommandline',
#  'String',
#  'return',
#  'cmdl',
#  'setCommandline',
#  'String',
#  'cmdl',
#  'commandline',
#  'setNewenvironment',
#  'boolean',
#  'newEnvironment',
#  'newenv',
#  'getEnvironment',
#  'String',
#  'if',
#  'env',
#  'newEnvironment',
#  'return',
#  'env',
#  'return',
#  'patchEnvironment',
#  'setEnvironment',
#  'String',
#  'env',
#  'env',
#  'setWorkingDirectory',
#  'File',
#  'if',
#  'wd',
#  'getAbsolutePath',
#  'equals',
#  'antWorkingDirectory',
#  'workingDirectory',
#  'workingDirectory',
#  'wd',
#  'setAntRun',
#  'Project',
#  'project',
#  'project',
#  'setVMLauncher',
#  'boolean',
#  'useVMLauncher',
#  'useVMLauncher',
#  'execute',
#  'int',
#  'CommandLauncher',
#  'launcher',
#  'vmLauncher',
#  'vmLauncher',
#  'shellLauncher',
#  'if',
#  'useVMLauncher',
#  'block',
#  'launcher',
#  'shellLauncher',
#  'Process',
#  'process',
#  'exec',
#  'project',
#  'getCommandline',
#  'getEnvironment',
#  'workingDirectory',
#  'try',
#  'setProcessInputStream',
#  'getOutputStream',
#  'setProcessOutputStream',
#  'getInputStream',
#  'setProcessErrorStream',
#  'getErrorStream',
#  'catch',
#  ['IOException'],
#  'destroy',
#  'throw',
#  'e',
#  'start',
#  'if',
#  'watchdog',
#  'start',
#  'process',
#  'waitFor',
#  'process',
#  'if',
#  'watchdog',
#  'stop',
#  'stop',
#  'if',
#  'watchdog',
#  'checkException',
#  'return',
#  'getExitValue',
#  'waitFor',
#  'Process',
#  'try',
#  'waitFor',
#  'setExitValue',
#  'exitValue',
#  'catch',
#  ['InterruptedException'],
#  'setExitValue',
#  'int',
#  'exitValue',
#  'value',
#  'getExitValue',
#  'int',
#  'return',
#  'exitValue',
#  'patchEnvironment',
#  'String',
#  'Vector',
#  'osEnv',
#  'Vector',
#  'getProcEnvironment',
#  'clone',
#  'for',
#  'int',
#  'i',
#  'i',
#  'length',
#  'i',
#  'block',
#  'int',
#  'pos',
#  'env',
#  'i',
#  'indexOf',
#  'String',
#  'key',
#  'env',
#  'i',
#  'substring',
#  'pos',
#  'int',
#  'size',
#  'size',
#  'for',
#  'int',
#  'j',
#  'j',
#  'size',
#  'j',
#  'block',
#  'if',
#  'String',
#  'elementAt',
#  'j',
#  'block',
#  'removeElementAt',
#  'j',
#  'break',
#  'addElement',
#  'env',
#  'i',
#  'String',
#  'result',
#  'String',
#  'size',
#  'copyInto',
#  'result',
#  'return',
#  'result',
#  'runCommand',
#  'Task',
#  'String',
#  'try',
#  'log',
#  'toString',
#  'cmdline',
#  'MSG_VERBOSE',
#  'Execute',
#  'exe',
#  'Execute',
#  'LogStreamHandler',
#  'task',
#  'MSG_INFO',
#  'MSG_ERR',
#  'setAntRun',
#  'getProject',
#  'setCommandline',
#  'cmdline',
#  'int',
#  'retval',
#  'execute',
#  'if',
#  'retval',
#  'block',
#  'throw',
#  'BuildException',
#  'cmdline',
#  'retval',
#  'getLocation',
#  'catch',
#  ['java.io.IOException'],
#  'throw',
#  'BuildException',
#  'cmdline',
#  'exc',
#  'getLocation',
#  'CommandLauncher',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'if',
#  'project',
#  'block',
#  'log',
#  'toString',
#  'cmd',
#  'MSG_DEBUG',
#  'return',
#  'getRuntime',
#  'exec',
#  'cmd',
#  'env',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'File',
#  'if',
#  'workingDir',
#  'block',
#  'return',
#  'exec',
#  'project',
#  'cmd',
#  'env',
#  'throw',
#  'IOException',
#  'Java11CommandLauncher',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'String',
#  'newcmd',
#  'String',
#  'length',
#  'for',
#  'int',
#  'i',
#  'i',
#  'length',
#  'i',
#  'block',
#  'newcmd',
#  'i',
#  'quoteArgument',
#  'cmd',
#  'i',
#  'if',
#  'project',
#  'block',
#  'log',
#  'toString',
#  'newcmd',
#  'MSG_DEBUG',
#  'return',
#  'getRuntime',
#  'exec',
#  'newcmd',
#  'env',
#  'CommandLauncher',
#  'Java13CommandLauncher',
#  'Java13CommandLauncher',
#  '_execWithCWD',
#  'getMethod',
#  'Class',
#  'String',
#  'String',
#  'File',
#  'Runtime',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'File',
#  'try',
#  'if',
#  'project',
#  'block',
#  'log',
#  'toString',
#  'cmd',
#  'MSG_DEBUG',
#  'Object',
#  'arguments',
#  'cmd',
#  'env',
#  'workingDir',
#  'return',
#  'Process',
#  'invoke',
#  'getRuntime',
#  'arguments',
#  'catch',
#  ['InvocationTargetException'],
#  'Throwable',
#  'realexc',
#  'getTargetException',
#  'if',
#  'realexc',
#  'ThreadDeath',
#  'block',
#  'throw',
#  'ThreadDeath',
#  'realexc',
#  'if',
#  'realexc',
#  'IOException',
#  'block',
#  'throw',
#  'IOException',
#  'realexc',
#  'block',
#  'throw',
#  'BuildException',
#  'realexc',
#  'catch',
#  ['Exception'],
#  'throw',
#  'BuildException',
#  'exc',
#  'Method',
#  '_execWithCWD',
#  'CommandLauncher',
#  'CommandLauncherProxy',
#  'CommandLauncherProxy',
#  'CommandLauncher',
#  '_launcher',
#  'launcher',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'return',
#  'exec',
#  'project',
#  'cmd',
#  'env',
#  'CommandLauncher',
#  '_launcher',
#  'CommandLauncher',
#  'WinNTCommandLauncher',
#  'WinNTCommandLauncher',
#  'CommandLauncher',
#  'launcher',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'File',
#  'File',
#  'commandDir',
#  'workingDir',
#  'if',
#  'workingDir',
#  'block',
#  'if',
#  'project',
#  'block',
#  'commandDir',
#  'getBaseDir',
#  'block',
#  'return',
#  'exec',
#  'project',
#  'cmd',
#  'env',
#  'int',
#  'preCmdLength',
#  'String',
#  'newcmd',
#  'String',
#  'length',
#  'preCmdLength',
#  'newcmd',
#  'newcmd',
#  'newcmd',
#  'newcmd',
#  'newcmd',
#  'getAbsolutePath',
#  'newcmd',
#  'arraycopy',
#  'cmd',
#  'newcmd',
#  'preCmdLength',
#  'length',
#  'return',
#  'exec',
#  'project',
#  'newcmd',
#  'env',
#  'CommandLauncherProxy',
#  'MacCommandLauncher',
#  'MacCommandLauncher',
#  'CommandLauncher',
#  'launcher',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'File',
#  'if',
#  'workingDir',
#  'block',
#  'return',
#  'exec',
#  'project',
#  'cmd',
#  'env',
#  'getProperties',
#  'put',
#  'getAbsolutePath',
#  'try',
#  'return',
#  'exec',
#  'project',
#  'cmd',
#  'env',
#  'getProperties',
#  'put',
#  'antWorkingDirectory',
#  'CommandLauncherProxy',
#  'ScriptCommandLauncher',
#  'ScriptCommandLauncher',
#  'String',
#  'CommandLauncher',
#  'launcher',
#  '_script',
#  'script',
#  'exec',
#  'Process',
#  'Project',
#  'String',
#  'String',
#  'File',
#  'if',
#  'project',
#  'block',
#  'if',
#  'workingDir',
#  'block',
#  'return',
#  'exec',
#  'project',
#  'cmd',
#  'env',
#  'throw',
#  'IOException',
#  'String',
#  'antHome',
#  'getProperty',
#  'if',
#  'antHome',
#  'block',
#  'throw',
#  'IOException',
#  'String',
#  'antRun',
#  'resolveFile',
#  'toString',
#  'antHome',
#  'separator',
#  '_script',
#  'File',
#  'commandDir',
#  'workingDir',
#  'if',
#  'workingDir',
#  'project',
#  'block',
#  'commandDir',
#  'getBaseDir',
#  'String',
#  'newcmd',
#  'String',
#  'length',
#  'newcmd',
#  'antRun',
#  'newcmd',
#  'getAbsolutePath',
#  'arraycopy',
#  'cmd',
#  'newcmd',
#  'length',
#  'return',
#  'exec',
#  'project',
#  'newcmd',
#  'env',
#  'String',
#  '_script',
#  'CommandLauncherProxy']
